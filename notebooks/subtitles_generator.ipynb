# %% [markdown]
# <a href="https://colab.research.google.com/github/davidkngo/Research/blob/master/notebooks/subtitles_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !mkdir -p /content/Studies
# !ln -s /content/gdrive/My\ Drive/Studies /content/Studies/gdrive
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/konverner/subtitles-generator.git
# %cd /content/subtitles-generator
# !pip install .
# Out:
# fatal: destination path 'subtitles-generator' already exists and is not an empty directory.
# /content/subtitles-generator
# Processing /content/subtitles-generator
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for subtitles-generator: filename=subtitles_generator-0.0.1-py3-none-any.whl size=8800 sha256=b31a5781a6c66a795890a5968afadf93b6ad74726911cb5077b14bb2c8d291d4
#   Stored in directory: /root/.cache/pip/wheels/52/94/ee/172286a922f75c16d8d14638e7c9dd10befe34eb18bbaa4d60
# Successfully built subtitles-generator
# ...
#   Attempting uninstall: subtitles-generator
#     Found existing installation: subtitles-generator 0.0.1
#     Uninstalling subtitles-generator-0.0.1:
#       Successfully uninstalled subtitles-generator-0.0.1
# ...

# %%
# !apt-get update
# !apt-get install -y ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,315 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy InRelease
# ...

# %%
# !pip3 install imageio==2.4.1

# %% [markdown]
# run with `large` `german` model on the video `videos/test.mp4`
#
# subtitles will be saved as `videos/test.srt`

# %%
# !ls -al /content/Studies/gdrive
# Out:
# lrwxrwxrwx 1 root root 32 Jan 28 11:11 /content/Studies/gdrive -> '/content/gdrive/My Drive/Studies'

# %%
import os
os.environ['IMAGEIO_FFMPEG_EXE'] = '/usr/bin/ffmpeg'

# !python main.py --model_size large --lang korean --input_file "/content/Studies/gdrive/Korean/Korean Movides/Yêu Lại Vợ Ngầu.mp4"
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Error while fetching file: HTTP Error 404: Not Found.
# Error while fetching file: HTTP Error 404: Not Found.
# Error while fetching file: HTTP Error 404: Not Found.
# Error while fetching file: HTTP Error 404: Not Found.
# Traceback (most recent call last):
#   File "/content/subtitles-generator/main.py", line 14, in <module>
#     from subtitles_generator.utils import create_srt, extract_audio
#   File "/usr/local/lib/python3.12/dist-packages/subtitles_generator/utils.py", line 13, in <module>
#     from moviepy.editor import VideoFileClip
#   File "/usr/local/lib/python3.12/dist-packages/moviepy/editor.py", line 26, in <module>
#     imageio.plugins.ffmpeg.download()
#   File "/usr/local/lib/python3.12/dist-packages/imageio/plugins/ffmpeg.py", line 79, in download
#     get_remote_file(fname=fname, directory=directory, force_download=force_download)
# ...
